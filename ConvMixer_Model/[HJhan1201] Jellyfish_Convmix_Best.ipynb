# %%
# 필요한 라이브러리 및 모듈을 가져옵니다.

import os
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report


import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Input, Conv2D, GlobalAveragePooling2D, BatchNormalization, DepthwiseConv2D, Activation, Add
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping

import seaborn as sns


# 설정 값들을 정의합니다.
IMG_SIZE = 40, 40  # 이미지 크기
BATCH_SIZE = 32  # 배치 크기
SEED = 5  # 랜덤 시드
AUTO = tf.data.AUTOTUNE  # TensorFlow의 데이터 파이프라인을 최적화하기 위한 설정

# %%
# 주어진 경로에서 이미지 파일들의 전체 경로를 생성하는 함수를 정의합니다.
def create_images_list(path):
    full_path = []
    images = os.listdir(path)
    for i in images:
        full_path.append(os.path.join(path, i))
    return full_path

# 각 클래스에 대한 이미지 경로를 생성합니다.
data_moon = create_images_list(os.getenv('HOME')+'/aiffel/jellyfish/Train_Test_Valid/Train/Moon_jellyfish')
data_barrel = create_images_list(os.getenv('HOME')+'/aiffel/jellyfish/Train_Test_Valid/Train/barrel_jellyfish')
data_blue = create_images_list(os.getenv('HOME')+'/aiffel/jellyfish/Train_Test_Valid/Train/blue_jellyfish')
data_compass = create_images_list(os.getenv('HOME')+'/aiffel/jellyfish/Train_Test_Valid/Train/compass_jellyfish')
data_lions_mane = create_images_list(os.getenv('HOME')+'/aiffel/jellyfish/Train_Test_Valid/Train/lions_mane_jellyfish')
data_mauve_stinger = create_images_list(os.getenv('HOME')+'/aiffel/jellyfish/Train_Test_Valid/Train/mauve_stinger_jellyfish')

# 클래스 레이블에 대한 룩업 테이블을 정의합니다.
jellyfish_classes = {0:'Moon', 1 : 'Barrel', 2 : 'Blue', 3 : 'Compass', 4 : 'Lion’s mane', 5: 'Mauve stinger'}

# 데이터프레임을 생성합니다.
data_df = pd.concat([pd.DataFrame({"img" : np.array(data_moon) , "label": 0 }),
                     pd.DataFrame({"img" : np.array(data_barrel) , "label": 1 }),
                     pd.DataFrame({"img" : np.array(data_blue) , "label": 2 }),
                     pd.DataFrame({"img" : np.array(data_compass) , "label": 3 }),
                     pd.DataFrame({"img" : np.array(data_lions_mane) , "label": 4 }),
                     pd.DataFrame({"img" : np.array(data_mauve_stinger) , "label": 5 }) ], ignore_index = True)

# 데이터를 섞고 인덱스를 재설정합니다.
data_df = shuffle(data_df, random_state = SEED).reset_index(drop = True)
data_df.head()
# Out:
#                                                  img  label
# 0  /aiffel/aiffel/jellyfish/Train_Test_Valid/Trai...      3
# 1  /aiffel/aiffel/jellyfish/Train_Test_Valid/Trai...      4
# 2  /aiffel/aiffel/jellyfish/Train_Test_Valid/Trai...      5
# 3  /aiffel/aiffel/jellyfish/Train_Test_Valid/Trai...      5
# 4  /aiffel/aiffel/jellyfish/Train_Test_Valid/Trai...      0

# %%
# 학습 및 검증용 데이터프레임과 테스트용 데이터프레임으로 나눕니다.
test_idx = data_df.shape[0] * 15 // 100  # 15 %를 테스트용으로 사용

train_df = data_df[test_idx:].reset_index(drop = True)
test_df = data_df[:test_idx].reset_index(drop = True)

# 데이터프레임 크기 출력
print("train_df (train and val) shape -> ", train_df.shape[0])
print("test_df shape -> ", test_df.shape[0])
# Out:
# train_df (train and val) shape ->  765
# test_df shape ->  135

# %%
# ConvMixer 블록을 정의하는 클래스를 생성합니다.
class ConvMixerBlock(Layer):
    def __init__(self, filters, kernel_size, patch_size, **kwargs):
        super(ConvMixerBlock, self).__init__(**kwargs)
        self.filters = filters
        self.kernel_size = kernel_size
        self.patch_size = patch_size
        
        self.deepwise = DepthwiseConv2D(kernel_size = kernel_size, padding = 'same')
        self.conv1 = Conv2D(filters, kernel_size = 1)
        self.act = Activation('gelu')
        self.bn1 = BatchNormalization()
        self.bn2 = BatchNormalization()

    def call(self, inputs):
        X = self.deepwise(inputs)
        X = self.act(X)
        X = self.bn1(X)
        X = Add()([X, inputs])
        X = self.conv1(X)
        X = self.act(X)
        X = self.bn2(X)
            
        return X
    
    def get_config(self):
        base_config = super().get_config()
        return {
            **base_config,
            "filters" : self.filters,
            "kernel_size": self.kernel_size,
            "patch_size": self.patch_size}

# %%
# 모델의 입력 레이어를 정의합니다.
FEATURES = 256
inp = Input(shape = (*IMG_SIZE, 3))

# 모델의 초기 Conv2D 레이어를 정의합니다.
X = Conv2D(FEATURES, 2, 2)(inp)
X = Activation('gelu')(X)
X = BatchNormalization()(X)

# ConvMixer 블록을 여러 개 쌓아 모델을 구성합니다.
X = ConvMixerBlock(FEATURES, 5, 2, name = 'CONVMIXER_1')(X)
X = ConvMixerBlock(FEATURES, 5, 2, name = 'CONVMIXER_2')(X)
X = ConvMixerBlock(FEATURES, 5, 2, name = 'CONVMIXER_3')(X)
X = ConvMixerBlock(FEATURES, 5, 2, name = 'CONVMIXER_4')(X)
X = ConvMixerBlock(FEATURES, 5, 2, name = 'CONVMIXER_5')(X)
X = ConvMixerBlock(FEATURES, 5, 2, name = 'CONVMIXER_6')(X)
X = ConvMixerBlock(FEATURES, 5, 2, name = 'CONVMIXER_7')(X)
X = ConvMixerBlock(FEATURES, 5, 2, name = 'CONVMIXER_8')(X)

# GlobalAveragePooling 레이어를 통해 공간 차원을 평균화합니다.
X = GlobalAveragePooling2D()(X)

# 출력 레이어를 정의합니다.
out = Dense(6, activation = 'softmax')(X)

# 전체 모델을 정의합니다.
model = Model(inputs = inp, outputs = out)
model.summary()

# 모델을 컴파일합니다.
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.01),
              loss = tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics = ['acc',tf.keras.metrics.SparseTopKCategoricalAccuracy(k=3, name="top_3_acc", dtype=None) ])
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 40, 40, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 20, 20, 256)       3328
# _________________________________________________________________
# activation (Activation)      (None, 20, 20, 256)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 20, 20, 256)       1024
# _________________________________________________________________
# CONVMIXER_1 (ConvMixerBlock) (None, 20, 20, 256)       74496
# _________________________________________________________________
# CONVMIXER_2 (ConvMixerBlock) (None, 20, 20, 256)       74496
# _________________________________________________________________
# CONVMIXER_3 (ConvMixerBlock) (None, 20, 20, 256)       74496
# _________________________________________________________________
# CONVMIXER_4 (ConvMixerBlock) (None, 20, 20, 256)       74496
# _________________________________________________________________
# CONVMIXER_5 (ConvMixerBlock) (None, 20, 20, 256)       74496
# _________________________________________________________________
# CONVMIXER_6 (ConvMixerBlock) (None, 20, 20, 256)       74496
# _________________________________________________________________
# CONVMIXER_7 (ConvMixerBlock) (None, 20, 20, 256)       74496
# _________________________________________________________________
# CONVMIXER_8 (ConvMixerBlock) (None, 20, 20, 256)       74496
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 1542
# =================================================================
# Total params: 601,862
# Trainable params: 593,158
# Non-trainable params: 8,704
# _________________________________________________________________

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
# 이미지를 로드하여 배열로 변환하는 함수
def load_and_preprocess_image(img_path):
    img = load_img(img_path, target_size=IMG_SIZE)
    img_array = img_to_array(img) / 255.0  # 이미지를 [0, 1] 범위로 정규화
    return img_array

# 학습 데이터를 로드하고 전처리합니다.
X_train = np.array([load_and_preprocess_image(img_path) for img_path in train_df['img']])
y_train = train_df['label'].values

# 검증 데이터를 로드하고 전처리합니다.
X_val = np.array([load_and_preprocess_image(img_path) for img_path in test_df['img']])
y_val = test_df['label'].values

# 모델을 컴파일합니다.
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['acc', tf.keras.metrics.SparseTopKCategoricalAccuracy(k=3, name="top_3_acc", dtype=None)])

# 모델을 학습시킵니다.
history = model.fit(X_train, y_train,
                    epochs=10,  # 원하는 에폭 수로 설정
                    batch_size=BATCH_SIZE,
                    validation_data=(X_val, y_val))

# 모델을 평가합니다.
test_loss, test_acc, test_top3_acc = model.evaluate(X_val, y_val)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}, Test Top-3 Accuracy: {test_top3_acc:.4f}")
# Out:
# Epoch 1/10
# 24/24 [==============================] - 8s 118ms/step - loss: 1.9179 - acc: 0.3190 - top_3_acc: 0.6876 - val_loss: 60.0450 - val_acc: 0.1185 - val_top_3_acc: 0.4444
# Epoch 2/10
# 24/24 [==============================] - 2s 90ms/step - loss: 1.4374 - acc: 0.4235 - top_3_acc: 0.8170 - val_loss: 23.0025 - val_acc: 0.1185 - val_top_3_acc: 0.4148
# Epoch 3/10
# 24/24 [==============================] - 2s 90ms/step - loss: 1.3342 - acc: 0.4667 - top_3_acc: 0.8510 - val_loss: 11.0194 - val_acc: 0.1407 - val_top_3_acc: 0.4889
# Epoch 4/10
# 24/24 [==============================] - 2s 90ms/step - loss: 1.3259 - acc: 0.5007 - top_3_acc: 0.8523 - val_loss: 7.6677 - val_acc: 0.1926 - val_top_3_acc: 0.5778
# Epoch 5/10
# 24/24 [==============================] - 2s 90ms/step - loss: 1.1236 - acc: 0.5660 - top_3_acc: 0.8993 - val_loss: 9.2843 - val_acc: 0.1259 - val_top_3_acc: 0.4667
# Epoch 6/10
# 24/24 [==============================] - 2s 90ms/step - loss: 1.0448 - acc: 0.5804 - top_3_acc: 0.9255 - val_loss: 3.4903 - val_acc: 0.2444 - val_top_3_acc: 0.6444
# Epoch 7/10
# 24/24 [==============================] - 2s 90ms/step - loss: 1.0240 - acc: 0.6092 - top_3_acc: 0.9137 - val_loss: 4.6779 - val_acc: 0.2000 - val_top_3_acc: 0.5926
# Epoch 8/10
# 24/24 [==============================] - 2s 91ms/step - loss: 0.9132 - acc: 0.6497 - top_3_acc: 0.9490 - val_loss: 3.8848 - val_acc: 0.1704 - val_top_3_acc: 0.5407
# Epoch 9/10
# 24/24 [==============================] - 2s 91ms/step - loss: 0.8745 - acc: 0.6706 - top_3_acc: 0.9320 - val_loss: 3.4949 - val_acc: 0.2593 - val_top_3_acc: 0.6222
# Epoch 10/10
# 24/24 [==============================] - 2s 91ms/step - loss: 0.8342 - acc: 0.6876 - top_3_acc: 0.9451 - val_loss: 2.7672 - val_acc: 0.2148 - val_top_3_acc: 0.6444
# 5/5 [==============================] - 0s 25ms/step - loss: 2.7672 - acc: 0.2148 - top_3_acc: 0.6444
# Test Loss: 2.7672, Test Accuracy: 0.2148, Test Top-3 Accuracy: 0.6444

# %% [markdown]
# ## val_acc: 0.1704, Test Accuracy: 0.1704
#
# ## 데이터 증강 추가

# %%
# 이미지를 로드하여 배열로 변환하는 함수
def load_and_preprocess_image(img_path):
    img = load_img(img_path, target_size=IMG_SIZE)
    img_array = img_to_array(img) / 255.0  # 이미지를 [0, 1] 범위로 정규화
    return img_array

# 데이터 증강을 위한 ImageDataGenerator 설정
datagen = ImageDataGenerator(
    rotation_range=20,      # 이미지 회전 각도 범위 (도)
    width_shift_range=0.2,  # 가로 방향으로 이미지 이동 비율
    height_shift_range=0.2, # 세로 방향으로 이미지 이동 비율
    shear_range=0.2,        # 전단 변형 강도
    zoom_range=0.2,         # 이미지 확대/축소 비율
    horizontal_flip=True,   # 수평 방향으로 뒤집기
    fill_mode='nearest'     # 이미지를 변형할 때 생기는 빈 픽셀을 채우는 방법
)

# 학습 데이터를 로드하고 전처리합니다.
X_train = np.array([load_and_preprocess_image(img_path) for img_path in train_df['img']])
y_train = train_df['label'].values

# 검증 데이터를 로드하고 전처리합니다.
X_val = np.array([load_and_preprocess_image(img_path) for img_path in test_df['img']])
y_val = test_df['label'].values

# 데이터 증강을 적용하고 배치 생성을 위한 generator 생성
train_datagen = datagen.flow(X_train, y_train, batch_size=BATCH_SIZE)

# 모델을 컴파일합니다.
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['acc', tf.keras.metrics.SparseTopKCategoricalAccuracy(k=3, name="top_3_acc", dtype=None)])

# 모델을 학습시킵니다.
history = model.fit(train_datagen,
                    epochs=10,  # 원하는 에폭 수로 설정
                    steps_per_epoch=len(X_train) // BATCH_SIZE,  # 한 에폭당 스텝 수
                    validation_data=(X_val, y_val))

# 모델을 평가합니다.
test_loss, test_acc, test_top3_acc = model.evaluate(X_val, y_val)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}, Test Top-3 Accuracy: {test_top3_acc:.4f}")
# Out:
# Epoch 1/10
# 23/23 [==============================] - 6s 112ms/step - loss: 1.3121 - acc: 0.5293 - top_3_acc: 0.8677 - val_loss: 14.2737 - val_acc: 0.1259 - val_top_3_acc: 0.5556
# Epoch 2/10
# 23/23 [==============================] - 2s 90ms/step - loss: 1.1862 - acc: 0.5362 - top_3_acc: 0.8854 - val_loss: 7.0681 - val_acc: 0.2370 - val_top_3_acc: 0.6148
# Epoch 3/10
# 23/23 [==============================] - 2s 90ms/step - loss: 1.0731 - acc: 0.5894 - top_3_acc: 0.9168 - val_loss: 4.9731 - val_acc: 0.2296 - val_top_3_acc: 0.5852
# Epoch 4/10
# 23/23 [==============================] - 2s 90ms/step - loss: 1.0278 - acc: 0.6139 - top_3_acc: 0.9168 - val_loss: 9.4252 - val_acc: 0.1778 - val_top_3_acc: 0.5556
# Epoch 5/10
# 23/23 [==============================] - 2s 91ms/step - loss: 0.9536 - acc: 0.6262 - top_3_acc: 0.9277 - val_loss: 5.3206 - val_acc: 0.3481 - val_top_3_acc: 0.7630
# Epoch 6/10
# 23/23 [==============================] - 2s 91ms/step - loss: 0.8500 - acc: 0.6971 - top_3_acc: 0.9441 - val_loss: 9.8723 - val_acc: 0.2889 - val_top_3_acc: 0.7259
# Epoch 7/10
# 23/23 [==============================] - 2s 91ms/step - loss: 0.8806 - acc: 0.6767 - top_3_acc: 0.9345 - val_loss: 2.6847 - val_acc: 0.4296 - val_top_3_acc: 0.7481
# Epoch 8/10
# 23/23 [==============================] - 2s 91ms/step - loss: 0.7860 - acc: 0.6944 - top_3_acc: 0.9618 - val_loss: 1.8061 - val_acc: 0.5111 - val_top_3_acc: 0.8963
# Epoch 9/10
# 23/23 [==============================] - 2s 91ms/step - loss: 0.6828 - acc: 0.7722 - top_3_acc: 0.9591 - val_loss: 1.9776 - val_acc: 0.5852 - val_top_3_acc: 0.8741
# Epoch 10/10
# 23/23 [==============================] - 2s 92ms/step - loss: 0.7603 - acc: 0.7258 - top_3_acc: 0.9632 - val_loss: 4.3396 - val_acc: 0.4148 - val_top_3_acc: 0.8148
# 5/5 [==============================] - 0s 20ms/step - loss: 4.3396 - acc: 0.4148 - top_3_acc: 0.8148
# Test Loss: 4.3396, Test Accuracy: 0.4148, Test Top-3 Accuracy: 0.8148

# %%
# 모델을 학습시킨 후에 주석 아래의 코드를 실행하여 결과를 시각화합니다.

# 훈련 손실과 정확도
train_loss = history.history['loss']
train_acc = history.history['acc']

# 검증 손실과 정확도
val_loss = history.history['val_loss']
val_acc = history.history['val_acc']

# 에폭 수
epochs = range(1, len(train_loss) + 1)

# 훈련 및 검증 손실 시각화
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'r^-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 정확도 시각화
plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r^-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# 그래프 표시
plt.show()

# %% [markdown]
# ## val_acc: 0.4000, Test Accuracy: 0.40
# ## 에폭 100으로 설정, 조기종료 추가, 히트맵 추가

# %%
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.utils.multiclass import unique_labels
# 조기 종료 콜백
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)


# 모델을 학습시킵니다.
history = model.fit(train_datagen,
                    epochs=100,  # 원하는 에폭 수로 설정
                    steps_per_epoch=len(X_train) // BATCH_SIZE,  # 한 에폭당 스텝 수
                    validation_data=(X_val, y_val))

# 모델을 평가합니다.
test_loss, test_acc, test_top3_acc = model.evaluate(X_val, y_val)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}, Test Top-3 Accuracy: {test_top3_acc:.4f}")

# 모델을 학습시킨 후에 주석 아래의 코드를 실행하여 결과를 시각화합니다.

# 훈련 손실과 정확도
train_loss = history.history['loss']
train_acc = history.history['acc']

# 검증 손실과 정확도
val_loss = history.history['val_loss']
val_acc = history.history['val_acc']

# 에폭 수
epochs = range(1, len(train_loss) + 1)


# 훈련 및 검증 손실 시각화
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'r^-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 훈련 및 검증 정확도 시각화
plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r^-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# 그래프 표시
plt.show()

# 모델 예측을 기반으로 한 히트맵 생성
y_pred = model.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)

# Confusion Matrix 생성
conf_matrix = confusion_matrix(y_val, y_pred_classes)

# 히트맵 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",
            xticklabels=unique_labels(y_val), yticklabels=unique_labels(y_val))
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Epoch 1/100
# 23/23 [==============================] - 2s 93ms/step - loss: 0.7960 - acc: 0.7312 - top_3_acc: 0.9386 - val_loss: 2.4563 - val_acc: 0.4741 - val_top_3_acc: 0.8074
# Epoch 2/100
# 23/23 [==============================] - 2s 91ms/step - loss: 0.6106 - acc: 0.7804 - top_3_acc: 0.9659 - val_loss: 1.2965 - val_acc: 0.6000 - val_top_3_acc: 0.9407
# Epoch 3/100
# 23/23 [==============================] - 2s 92ms/step - loss: 0.5888 - acc: 0.7694 - top_3_acc: 0.9714 - val_loss: 1.3667 - val_acc: 0.6296 - val_top_3_acc: 0.9333
# Epoch 4/100
# 23/23 [==============================] - 2s 91ms/step - loss: 0.4777 - acc: 0.8117 - top_3_acc: 0.9850 - val_loss: 1.3684 - val_acc: 0.6074 - val_top_3_acc: 0.9407
# Epoch 5/100
# 23/23 [==============================] - 2s 91ms/step - loss: 0.5226 - acc: 0.8063 - top_3_acc: 0.9850 - val_loss: 1.9923 - val_acc: 0.5185 - val_top_3_acc: 0.8370
# Epoch 6/100
# 23/23 [==============================] - 2s 91ms/step - loss: 0.5544 - acc: 0.8022 - top_3_acc: 0.9768 - val_loss: 1.9145 - val_acc: 0.4815 - val_top_3_acc: 0.8815
# Epoch 7/100
# 23/23 [==============================] - 2s 91ms/step - loss: 0.5884 - acc: 0.7935 - top_3_acc: 0.9688 - val_loss: 1.8245 - val_acc: 0.5926 - val_top_3_acc: 0.9037
# Epoch 8/100
# 23/23 [==============================] - 2s 91ms/step - loss: 0
100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1140 - acc: 0.9632 - top_3_acc: 0.9986 - val_loss: 0.3423 - val_acc: 0.9037 - val_top_3_acc: 0.9852
# Epoch 48/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1379 - acc: 0.9563 - top_3_acc: 0.9986 - val_loss: 1.1595 - val_acc: 0.6889 - val_top_3_acc: 0.9259
# Epoch 49/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1280 - acc: 0.9523 - top_3_acc: 1.0000 - val_loss: 0.3509 - val_acc: 0.9111 - val_top_3_acc: 0.9852
# Epoch 50/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0948 - acc: 0.9673 - top_3_acc: 1.0000 - val_loss: 0.6507 - val_acc: 0.8667 - val_top_3_acc: 0.9852
# Epoch 51/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0956 - acc: 0.9659 - top_3_acc: 0.9973 - val_loss: 0.7210 - val_acc: 0.8444 - val_top_3_acc: 0.9926
# Epoch 52/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1489 - acc: 0.9482 - top_3_acc: 0.9986 - val_loss: 0.7434 - val_acc: 0.8148 - val_top_3_acc: 0.9704
# Epoch 53/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.2097 - acc: 0.9236 - top_3_acc: 0.9973 - val_loss: 0.4232 - val_acc: 0.8815 - val_top_3_acc: 0.9852
# Epoch 54/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1322 - acc: 0.9563 - top_3_acc: 0.9986 - val_loss: 1.0319 - val_acc: 0.7778 - val_top_3_acc: 0.9556
# Epoch 55/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1552 - acc: 0.9495 - top_3_acc: 1.0000 - val_loss: 0.6210 - val_acc: 0.8296 - val_top_3_acc: 0.9704
# Epoch 56/100
# 23/23 [==============================] - 2s 92ms/step - loss: 0.1692 - acc: 0.9359 - top_3_acc: 0.9986 - val_loss: 0.3372 - val_acc: 0.8815 - val_top_3_acc: 0.9852
# Epoch 57/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1177 - acc: 0.9632 - top_3_acc: 1.0000 - val_loss: 0.3518 - val_acc: 0.8815 - val_top_3_acc: 0.9778
# Epoch 58/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0868 - acc: 0.9645 - top_3_acc: 1.0000 - val_loss: 0.3018 - val_acc: 0.9259 - val_top_3_acc: 0.9926
# Epoch 59/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1257 - acc: 0.9618 - top_3_acc: 1.0000 - val_loss: 0.3118 - val_acc: 0.9037 - val_top_3_acc: 0.9852
# Epoch 60/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0848 - acc: 0.9700 - top_3_acc: 1.0000 - val_loss: 0.5368 - val_acc: 0.9259 - val_top_3_acc: 0.9778
# Epoch 61/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0759 - acc: 0.9782 - top_3_acc: 0.9986 - val_loss: 0.1730 - val_acc: 0.9704 - val_top_3_acc: 0.9926
# Epoch 62/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0569 - acc: 0.9795 - top_3_acc: 1.0000 - val_loss: 0.2364 - val_acc: 0.9556 - val_top_3_acc: 0.9926
# Epoch 63/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0755 - acc: 0.9782 - top_3_acc: 1.0000 - val_loss: 0.2271 - val_acc: 0.9259 - val_top_3_acc: 1.0000
# Epoch 64/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0986 - acc: 0.9660 - top_3_acc: 0.9946 - val_loss: 0.3912 - val_acc: 0.9037 - val_top_3_acc: 0.9852
# Epoch 65/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0514 - acc: 0.9754 - top_3_acc: 1.0000 - val_loss: 0.6041 - val_acc: 0.8519 - val_top_3_acc: 0.9630
# Epoch 66/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1185 - acc: 0.9577 - top_3_acc: 0.9973 - val_loss: 1.0030 - val_acc: 0.8222 - val_top_3_acc: 0.9852
# Epoch 67/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1016 - acc: 0.9700 - top_3_acc: 0.9986 - val_loss: 0.4273 - val_acc: 0.9111 - val_top_3_acc: 0.9852
# Epoch 68/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1014 - acc: 0.9727 - top_3_acc: 0.9973 - val_loss: 0.4221 - val_acc: 0.8889 - val_top_3_acc: 1.0000
# Epoch 69/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0662 - acc: 0.9727 - top_3_acc: 1.0000 - val_loss: 0.4239 - val_acc: 0.8963 - val_top_3_acc: 0.9852
# Epoch 70/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1172 - acc: 0.9659 - top_3_acc: 0.9986 - val_loss: 0.5411 - val_acc: 0.8148 - val_top_3_acc: 0.9704
# Epoch 71/100
# 23/23 [==============================] - 2s 91ms/step - loss: 0.0760 - acc: 0.9715 - top_3_acc: 1.0000 - val_loss: 0.8067 - val_acc: 0.8370 - val_top_3_acc: 0.9778
# Epoch 72/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0904 - acc: 0.9659 - top_3_acc: 0.9986 - val_loss: 1.0762 - val_acc: 0.8296 - val_top_3_acc: 0.9630
# Epoch 73/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1489 - acc: 0.9550 - top_3_acc: 0.9986 - val_loss: 0.3831 - val_acc: 0.8963 - val_top_3_acc: 0.9852
# Epoch 74/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1305 - acc: 0.9604 - top_3_acc: 0.9973 - val_loss: 0.8483 - val_acc: 0.8370 - val_top_3_acc: 0.9481
# Epoch 75/100
# 23/23 [==============================] - 2s 91ms/step - loss: 0.0632 - acc: 0.9795 - top_3_acc: 1.0000 - val_loss: 0.3661 - val_acc: 0.8963 - val_top_3_acc: 0.9926
# Epoch 76/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0994 - acc: 0.9727 - top_3_acc: 1.0000 - val_loss: 0.2533 - val_acc: 0.9407 - val_top_3_acc: 0.9926
# Epoch 77/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1285 - acc: 0.9591 - top_3_acc: 1.0000 - val_loss: 0.2648 - val_acc: 0.8963 - val_top_3_acc: 0.9926
# Epoch 78/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1272 - acc: 0.9645 - top_3_acc: 1.0000 - val_loss: 0.9196 - val_acc: 0.8444 - val_top_3_acc: 0.9704
# Epoch 79/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0928 - acc: 0.9714 - top_3_acc: 0.9986 - val_loss: 0.6052 - val_acc: 0.8889 - val_top_3_acc: 0.9778
# Epoch 80/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0972 - acc: 0.9659 - top_3_acc: 1.0000 - val_loss: 0.4052 - val_acc: 0.9259 - val_top_3_acc: 0.9778
# Epoch 81/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0906 - acc: 0.9673 - top_3_acc: 1.0000 - val_loss: 0.3857 - val_acc: 0.9111 - val_top_3_acc: 0.9926
# Epoch 82/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0745 - acc: 0.9755 - top_3_acc: 1.0000 - val_loss: 0.3770 - val_acc: 0.9185 - val_top_3_acc: 0.9926
# Epoch 83/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0690 - acc: 0.9700 - top_3_acc: 0.9986 - val_loss: 0.3054 - val_acc: 0.9259 - val_top_3_acc: 0.9852
# Epoch 84/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0774 - acc: 0.9686 - top_3_acc: 1.0000 - val_loss: 0.5142 - val_acc: 0.8963 - val_top_3_acc: 0.9778
# Epoch 85/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0724 - acc: 0.9714 - top_3_acc: 1.0000 - val_loss: 0.3147 - val_acc: 0.9185 - val_top_3_acc: 0.9852
# Epoch 86/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0482 - acc: 0.9850 - top_3_acc: 1.0000 - val_loss: 0.2958 - val_acc: 0.9111 - val_top_3_acc: 1.0000
# Epoch 87/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1052 - acc: 0.9700 - top_3_acc: 0.9986 - val_loss: 0.3699 - val_acc: 0.8889 - val_top_3_acc: 1.0000
# Epoch 88/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1138 - acc: 0.9604 - top_3_acc: 1.0000 - val_loss: 0.3852 - val_acc: 0.9037 - val_top_3_acc: 0.9926
# Epoch 89/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1206 - acc: 0.9645 - top_3_acc: 1.0000 - val_loss: 0.3909 - val_acc: 0.9037 - val_top_3_acc: 0.9852
# Epoch 90/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1203 - acc: 0.9563 - top_3_acc: 0.9986 - val_loss: 1.0653 - val_acc: 0.7704 - val_top_3_acc: 0.9333
# Epoch 91/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1307 - acc: 0.9591 - top_3_acc: 0.9986 - val_loss: 1.0278 - val_acc: 0.8074 - val_top_3_acc: 0.9556
# Epoch 92/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0759 - acc: 0.9768 - top_3_acc: 1.0000 - val_loss: 0.8748 - val_acc: 0.8593 - val_top_3_acc: 0.9630
# Epoch 93/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1226 - acc: 0.9591 - top_3_acc: 1.0000 - val_loss: 0.5580 - val_acc: 0.8148 - val_top_3_acc: 0.9852
# Epoch 94/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.1007 - acc: 0.9577 - top_3_acc: 1.0000 - val_loss: 0.3807 - val_acc: 0.9111 - val_top_3_acc: 0.9778
# Epoch 95/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0837 - acc: 0.9700 - top_3_acc: 1.0000 - val_loss: 0.5809 - val_acc: 0.8593 - val_top_3_acc: 0.9778
# Epoch 96/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0835 - acc: 0.9782 - top_3_acc: 0.9986 - val_loss: 0.3193 - val_acc: 0.9037 - val_top_3_acc: 0.9778
# Epoch 97/100
# 23/23 [==============================] - 2s 91ms/step - loss: 0.0498 - acc: 0.9851 - top_3_acc: 0.9986 - val_loss: 0.2575 - val_acc: 0.9407 - val_top_3_acc: 0.9926
# Epoch 98/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0541 - acc: 0.9836 - top_3_acc: 1.0000 - val_loss: 0.2510 - val_acc: 0.9481 - val_top_3_acc: 1.0000
# Epoch 99/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0649 - acc: 0.9754 - top_3_acc: 1.0000 - val_loss: 0.2486 - val_acc: 0.9481 - val_top_3_acc: 1.0000
# Epoch 100/100
# 23/23 [==============================] - 2s 90ms/step - loss: 0.0836 - acc: 0.9741 - top_3_acc: 0.9986 - val_loss: 0.4367 - val_acc: 0.9037 - val_top_3_acc: 0.9926
# 5/5 [==============================] - 0s 20ms/step - loss: 0.4367 - acc: 0.9037 - top_3_acc: 0.9926
# Test Loss: 0.4367, Test Accuracy: 0.9037, Test Top-3 Accuracy: 0.9926

# %% [markdown]
# ## val_acc: 0.9037, Test Accuracy: 0.9037
#
# ## 학습속도도 빠르고 정확도가 높았다.
